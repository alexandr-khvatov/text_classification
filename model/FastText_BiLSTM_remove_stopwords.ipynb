# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandr-khvatov/text_classification/blob/main/model/FastText_BiLSTM_remove_stopwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymorphy2 --quiet
# !pip install navec --quiet
# !pip install wget --quiet
# !pip install gensim==3.8.3 --quiet
# !pip install compress-fasttext==0.0.1 --quiet
# Out:
#      |████████████████████████████████| 55 kB 753 kB/s
#      |████████████████████████████████| 8.2 MB 36.3 MB/s
#   Building wheel for docopt (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
#      |████████████████████████████████| 24.2 MB 1.3 MB/s
#      |████████████████████████████████| 161 kB 13.6 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 241 kB 63.5 MB/s
#   Building wheel for compress-fasttext (setup.py) ... done
#   Building wheel for pqkmeans (PEP 517) ... done
#   Building wheel for texmex-python (setup.py) ... done
#   Building wheel for lshash3 (setup.py) ... done

# %%
import wget
import os
import sys
import re
import statistics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pymorphy2
import sklearn
from google.colab import drive
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from wordcloud import WordCloud
import compress_fasttext
import gensim

# %% [markdown]
# # **Get cleaned dataset**

# %%
url = 'https://raw.githubusercontent.com/alexandr-khvatov/text_classification/main/data/data_cleaned_RU_remove_stopwords.csv'

PATH_CLEANED_DATASET = 'data_cleaned_RU_remove_stopwords.csv'
if not os.path.exists(PATH_CLEANED_DATASET):
    wget.download(url)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Parse**

# %%
df = pd.read_csv(PATH_CLEANED_DATASET)
df=df.astype({'toxic': 'int64'})
df.sample(10)
# Out:
#                                                  comment  toxic
# 12214  видимо подъезд просьба выкидывать пресса специ...      0
# 5665   такой ясный хуй завести трактор особый любовь ...      1
# 3497   диета просто сразу сначала преодолеть сахарный...      0
# 11843  видеть пост вк фотка слабый незаметный удар од...      1
# 11715  речь использовать обычный поводок ошейник намо...      0
# 6755   этот сраный фишка западный околонаучный переда...      1
# 13088                прям описать делать последний месяц      0
# 12183                                 мусор путь вынести      1
# 6899   сказать автоматически бороться идея фашистский...      1
# 6181   мочь точно сказать дело карта иметь склоняться...      0

# %%
print("max :",df.comment.str.len().max())
print("min :",df.comment.str.len().min())
print("mean :",df.comment.str.len().mean())
# Out:
# max : 5943
# min : 2
# mean : 127.40542980141647

# %%
print("max: ",max(list(map(lambda comment: len(comment.split()),df.comment))))
print("min: ",min(list(map(lambda comment: len(comment.split()),df.comment))))
print("mean: ",statistics.mean(list(map(lambda comment: len(comment.split()),df.comment))))
plt.plot(df.comment.index,list(map(lambda comment: len(comment.split()),df.comment)))
# Out:
# max:  717
# min:  1
# mean:  16.417372587140676

# %%
sentences = df.comment.values
labels = df.toxic.values

# %%
X_train, X_test, y_train, y_test = train_test_split(sentences, labels, test_size=.2, random_state=42)

# %%
X_train.shape
# Out:
# (11521,)

# %% [markdown]
# [FastText Embedding by David Dale](https://github.com/avidale/compress-fasttext/releases/tag/v0.0.1)

# %%
import compress_fasttext
# url = 'https://github.com/avidale/compress-fasttext/releases/download/v0.0.1/ft_freqprune_100K_20K_pq_300.bin'

# print(small_model['спасибо'])
# # [ 0.26762889  0.35489027 ...  -0.06149674] # a 300-dimensional vector
# print(small_model.most_similar('котенок'))


# import fasttext
url = 'https://github.com/avidale/compress-fasttext/releases/download/v0.0.1/ft_freqprune_100K_20K_pq_300.bin'
PATH_FASTTEXT = 'ft_freqprune_100K_20K_pq_300.bin'



if not os.path.exists(PATH_FASTTEXT):
    wget.download(url)
    
# ft = fasttext.load_model('ft_freqprune_100K_20K_pq_300.bin')

ft = gensim.models.fasttext.FastTextKeyedVectors.load('ft_freqprune_100K_20K_pq_300.bin')
print(ft['jhsfbjhsg'].shape)
# Out:
# (300,)

# %%
PAD_TOKEN = '<pad>'

# %%
def vectorize_sentence(sentence: str, vectorizer=ft, pad_token = PAD_TOKEN, max_sequence_length=30) -> np.array:
    tokens = sentence.split()
    embedd_tokens = [vectorizer.get_vector(t) for t in tokens[:max_sequence_length]]
    if len(embedd_tokens) < max_sequence_length:
        embedd_tokens += [vectorizer[pad_token]] * (max_sequence_length - len(embedd_tokens))
    return np.array(embedd_tokens)

# %%
# получить длину(количество слов) отзывов в 75% датасета
sequence_length=int(round(np.percentile(list(map(lambda sentence: len(sentence.split()), X_train)), 75)))

# %%
sequence_length
# Out:
# 18

# %% [markdown]
# # Word Vectorizer

# %%
X_train = np.array(list(map(
    lambda sentence:vectorize_sentence(
        sentence,
        vectorizer=ft,
        pad_token = PAD_TOKEN,
        max_sequence_length=sequence_length),
    X_train.flatten()
    )
))

X_test = np.array(list(map(
    lambda sentence:vectorize_sentence(
        sentence,
        vectorizer=ft,
        pad_token = PAD_TOKEN,
        max_sequence_length=sequence_length),
    X_test.flatten()
    )
))

# %%
X_train.shape
# Out:
# (11521, 18, 300)

# %%
ft[PAD_TOKEN].shape[0]
# Out:
# 300

# %%
DIMENSION_EMBEDDING=ft[PAD_TOKEN].shape[0]

# %% [markdown]
# # Build model  BiLSTM

# %%
import tensorflow as tf
from tensorflow.keras.metrics import TruePositives,FalsePositives,TrueNegatives,FalseNegatives,BinaryAccuracy,Precision,Recall,AUC,AUC
from tensorflow.keras import Sequential,losses
from tensorflow.keras.layers import Input, Dense, Dropout,Bidirectional,LSTM,SpatialDropout1D,GlobalMaxPool1D
from tensorflow.keras.utils import plot_model

METRICS = [
      TruePositives(name='tp'),
      FalsePositives(name='fp'),
      TrueNegatives(name='tn'),
      FalseNegatives(name='fn'), 
      BinaryAccuracy(name='accuracy'),
      Precision(name='precision'),
      Recall(name='recall'),
      AUC(name='auc'),
      AUC(name='prc', curve='PR'), # precision-recall curve
]

MODEL_NAME = 'FASTTEXT-RusVectores_BiLSTM'
SEED = 42
SPLIT = 0.2
EPOCHS = 50
BATCH_SIZE = 512

negative_count, neutral_count = np.bincount(y_train)

initial_output_bias = tf.keras.initializers.Constant(
    np.log([neutral_count/negative_count])
)

model = tf.keras.Sequential(
    [
    Input(shape=(sequence_length, DIMENSION_EMBEDDING,),dtype=tf.float32),
    SpatialDropout1D(0.2),
    Bidirectional(LSTM(256, recurrent_dropout=0.1, return_sequences=True)),
    GlobalMaxPool1D(),
    Dropout(rate=0.5, seed=SEED),
    Dense(64, activation='relu'),
    Dropout(rate=0.5, seed=SEED),
    Dense(1,bias_initializer=initial_output_bias,activation='sigmoid'),
]
,name=MODEL_NAME)

model.compile(
    loss=losses.BinaryCrossentropy(from_logits=False),
    optimizer='adam',
    metrics=METRICS
)
model.summary()

plot_model(model,
           to_file='model.png',
           show_shapes=True,
           show_layer_names=True,
           layer_range=None,
            show_layer_activations=True)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "FASTTEXT-RusVectores_BiLSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  spatial_dropout1d (SpatialD  (None, 18, 300)          0
#  ropout1D)
#
#  bidirectional (Bidirectiona  (None, 18, 512)          1140736
#  l)
#
#  global_max_pooling1d (Globa  (None, 512)              0
#  lMaxPooling1D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 1,173,633
# Trainable params: 1,173,633
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=5,
    verbose=1,
    restore_best_weights=True
)

def calculate_weights(pos_count, neg_count):
    total = pos_count + neg_count
    return {
        0: (1 / neg_count) * total / 2.0,
        1: (1 / pos_count) * total / 2.0
    }

history = model.fit(
    x=X_train,
    y=y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=SPLIT,
    callbacks=[early_stopping],
    class_weight=calculate_weights(neutral_count, negative_count),
)
# Out:
# Epoch 1/50
# 18/18 [==============================] - 10s 159ms/step - loss: 0.6281 - tp: 1822.0000 - fp: 1997.0000 - tn: 4163.0000 - fn: 1234.0000 - accuracy: 0.6494 - precision: 0.4771 - recall: 0.5962 - auc: 0.6977 - prc: 0.5211 - val_loss: 0.4508 - val_tp: 602.0000 - val_fp: 271.0000 - val_tn: 1245.0000 - val_fn: 187.0000 - val_accuracy: 0.8013 - val_precision: 0.6896 - val_recall: 0.7630 - val_auc: 0.8648 - val_prc: 0.7586
# Epoch 2/50
# 18/18 [==============================] - 2s 85ms/step - loss: 0.4369 - tp: 2461.0000 - fp: 1195.0000 - tn: 4965.0000 - fn: 595.0000 - accuracy: 0.8058 - precision: 0.6731 - recall: 0.8053 - auc: 0.8804 - prc: 0.7725 - val_loss: 0.3895 - val_tp: 629.0000 - val_fp: 245.0000 - val_tn: 1271.0000 - val_fn: 160.0000 - val_accuracy: 0.8243 - val_precision: 0.7197 - val_recall: 0.7972 - val_auc: 0.9011 - val_prc: 0.8225
# Epoch 3/50
# 18/18 [==============================] - 1s 83ms/step - loss: 0.3905 - tp: 2533.0000 - fp: 1046.0000 - tn: 5114.0000 - fn: 523.0000 - accuracy: 0.8298 - precision: 0.7077 - recall: 0.8289 - auc: 0.9046 - prc: 0.8158 - val_loss: 0.3976 - val_tp: 665.0000 - val_fp: 295.0000 - val_tn: 1221.0000 - val_fn: 124.0000 - val_accuracy: 0.8182 - val_precision: 0.6927 - val_recall: 0.8428 - val_auc: 0.9090 - val_prc: 0.8371
# Epoch 4/50
# 18/18 [==============================] - 2s 84ms/step - loss: 0.3899 - tp: 2539.0000 - fp: 973.0000 - tn: 5187.0000 - fn: 517.0000 - accuracy: 0.8383 - precision: 0.7229 - recall: 0.8308 - auc: 0.9062 - prc: 0.8238 - val_loss: 0.3776 - val_tp: 665.0000 - val_fp: 282.0000 - val_tn: 1234.0000 - val_fn: 124.0000 - val_accuracy: 0.8239 - val_precision: 0.7022 - val_recall: 0.8428 - val_auc: 0.9151 - val_prc: 0.8503
# Epoch 5/50
# 18/18 [==============================] - 2s 85ms/step - loss: 0.3737 - tp: 2588.0000 - fp: 979.0000 - tn: 5181.0000 - fn: 468.0000 - accuracy: 0.8430 - precision: 0.7255 - recall: 0.8469 - auc: 0.9136 - prc: 0.8331 - val_loss: 0.3815 - val_tp: 681.0000 - val_fp: 298.0000 - val_tn: 1218.0000 - val_fn: 108.0000 - val_accuracy: 0.8239 - val_precision: 0.6956 - val_recall: 0.8631 - val_auc: 0.9156 - val_prc: 0.8517
# Epoch 6/50
# 18/18 [==============================] - 2s 88ms/step - loss: 0.3644 - tp: 2609.0000 - fp: 1003.0000 - tn: 5157.0000 - fn: 447.0000 - accuracy: 0.8427 - precision: 0.7223 - recall: 0.8537 - auc: 0.9177 - prc: 0.8380 - val_loss: 0.4077 - val_tp: 699.0000 - val_fp: 335.0000 - val_tn: 1181.0000 - val_fn: 90.0000 - val_accuracy: 0.8156 - val_precision: 0.6760 - val_recall: 0.8859 - val_auc: 0.9163 - val_prc: 0.8507
# Epoch 7/50
# 18/18 [==============================] - 2s 84ms/step - loss: 0.3497 - tp: 2622.0000 - fp: 917.0000 - tn: 5243.0000 - fn: 434.0000 - accuracy: 0.8534 - precision: 0.7409 - recall: 0.8580 - auc: 0.9246 - prc: 0.8565 - val_loss: 0.3853 - val_tp: 683.0000 - val_fp: 303.0000 - val_tn: 1213.0000 - val_fn: 106.0000 - val_accuracy: 0.8226 - val_precision: 0.6927 - val_recall: 0.8657 - val_auc: 0.9208 - val_prc: 0.8592
# Epoch 8/50
# 18/18 [==============================] - 2s 87ms/step - loss: 0.3484 - tp: 2630.0000 - fp: 947.0000 - tn: 5213.0000 - fn: 426.0000 - accuracy: 0.8510 - precision: 0.7353 - recall: 0.8606 - auc: 0.9248 - prc: 0.8529 - val_loss: 0.3365 - val_tp: 630.0000 - val_fp: 187.0000 - val_tn: 1329.0000 - val_fn: 159.0000 - val_accuracy: 0.8499 - val_precision: 0.7711 - val_recall: 0.7985 - val_auc: 0.9235 - val_prc: 0.8647
# Epoch 9/50
# 18/18 [==============================] - 1s 84ms/step - loss: 0.3312 - tp: 2628.0000 - fp: 872.0000 - tn: 5288.0000 - fn: 428.0000 - accuracy: 0.8589 - precision: 0.7509 - recall: 0.8599 - auc: 0.9322 - prc: 0.8686 - val_loss: 0.3605 - val_tp: 677.0000 - val_fp: 267.0000 - val_tn: 1249.0000 - val_fn: 112.0000 - val_accuracy: 0.8356 - val_precision: 0.7172 - val_recall: 0.8580 - val_auc: 0.9231 - val_prc: 0.8636
# Epoch 10/50
# 18/18 [==============================] - 2s 85ms/step - loss: 0.3296 - tp: 2649.0000 - fp: 877.0000 - tn: 5283.0000 - fn: 407.0000 - accuracy: 0.8607 - precision: 0.7513 - recall: 0.8668 - auc: 0.9334 - prc: 0.8683 - val_loss: 0.3390 - val_tp: 657.0000 - val_fp: 209.0000 - val_tn: 1307.0000 - val_fn: 132.0000 - val_accuracy: 0.8521 - val_precision: 0.7587 - val_recall: 0.8327 - val_auc: 0.9243 - val_prc: 0.8685
# Epoch 11/50
# 18/18 [==============================] - 1s 82ms/step - loss: 0.3105 - tp: 2693.0000 - fp: 842.0000 - tn: 5318.0000 - fn: 363.0000 - accuracy: 0.8692 - precision: 0.7618 - recall: 0.8812 - auc: 0.9406 - prc: 0.8835 - val_loss: 0.3341 - val_tp: 650.0000 - val_fp: 194.0000 - val_tn: 1322.0000 - val_fn: 139.0000 - val_accuracy: 0.8555 - val_precision: 0.7701 - val_recall: 0.8238 - val_auc: 0.9288 - val_prc: 0.8730
# Epoch 12/50
# 18/18 [==============================] - 2s 84ms/step - loss: 0.3071 - tp: 2690.0000 - fp: 825.0000 - tn: 5335.0000 - fn: 366.0000 - accuracy: 0.8708 - precision: 0.7653 - recall: 0.8802 - auc: 0.9421 - prc: 0.8843 - val_loss: 0.3507 - val_tp: 688.0000 - val_fp: 252.0000 - val_tn: 1264.0000 - val_fn: 101.0000 - val_accuracy: 0.8469 - val_precision: 0.7319 - val_recall: 0.8720 - val_auc: 0.9286 - val_prc: 0.8717
# Epoch 13/50
# 18/18 [==============================] - 2s 86ms/step - loss: 0.3020 - tp: 2697.0000 - fp: 862.0000 - tn: 5298.0000 - fn: 359.0000 - accuracy: 0.8675 - precision: 0.7578 - recall: 0.8825 - auc: 0.9439 - prc: 0.8904 - val_loss: 0.3390 - val_tp: 657.0000 - val_fp: 219.0000 - val_tn: 1297.0000 - val_fn: 132.0000 - val_accuracy: 0.8477 - val_precision: 0.7500 - val_recall: 0.8327 - val_auc: 0.9274 - val_prc: 0.8711
# Epoch 14/50
# 18/18 [==============================] - 2s 85ms/step - loss: 0.2991 - tp: 2691.0000 - fp: 780.0000 - tn: 5380.0000 - fn: 365.0000 - accuracy: 0.8758 - precision: 0.7753 - recall: 0.8806 - auc: 0.9454 - prc: 0.8924 - val_loss: 0.4155 - val_tp: 731.0000 - val_fp: 388.0000 - val_tn: 1128.0000 - val_fn: 58.0000 - val_accuracy: 0.8065 - val_precision: 0.6533 - val_recall: 0.9265 - val_auc: 0.9301 - val_prc: 0.8736
# Epoch 15/50
# 18/18 [==============================] - 2s 85ms/step - loss: 0.3005 - tp: 2731.0000 - fp: 872.0000 - tn: 5288.0000 - fn: 325.0000 - accuracy: 0.8701 - precision: 0.7580 - recall: 0.8937 - auc: 0.9442 - prc: 0.8886 - val_loss: 0.3219 - val_tp: 642.0000 - val_fp: 165.0000 - val_tn: 1351.0000 - val_fn: 147.0000 - val_accuracy: 0.8646 - val_precision: 0.7955 - val_recall: 0.8137 - val_auc: 0.9312 - val_prc: 0.8783
# Epoch 16/50
# 18/18 [==============================] - 2s 86ms/step - loss: 0.2691 - tp: 2737.0000 - fp: 675.0000 - tn: 5485.0000 - fn: 319.0000 - accuracy: 0.8921 - precision: 0.8022 - recall: 0.8956 - auc: 0.9553 - prc: 0.9077 - val_loss: 0.3465 - val_tp: 654.0000 - val_fp: 190.0000 - val_tn: 1326.0000 - val_fn: 135.0000 - val_accuracy: 0.8590 - val_precision: 0.7749 - val_recall: 0.8289 - val_auc: 0.9292 - val_prc: 0.8773
# Epoch 17/50
# 18/18 [==============================] - 2s 88ms/step - loss: 0.2638 - tp: 2751.0000 - fp: 727.0000 - tn: 5433.0000 - fn: 305.0000 - accuracy: 0.8880 - precision: 0.7910 - recall: 0.9002 - auc: 0.9568 - prc: 0.9089 - val_loss: 0.3369 - val_tp: 663.0000 - val_fp: 192.0000 - val_tn: 1324.0000 - val_fn: 126.0000 - val_accuracy: 0.8620 - val_precision: 0.7754 - val_recall: 0.8403 - val_auc: 0.9313 - val_prc: 0.8783
# Epoch 18/50
# 18/18 [==============================] - 2s 84ms/step - loss: 0.2511 - tp: 2779.0000 - fp: 674.0000 - tn: 5486.0000 - fn: 277.0000 - accuracy: 0.8968 - precision: 0.8048 - recall: 0.9094 - auc: 0.9607 - prc: 0.9173 - val_loss: 0.3346 - val_tp: 660.0000 - val_fp: 175.0000 - val_tn: 1341.0000 - val_fn: 129.0000 - val_accuracy: 0.8681 - val_precision: 0.7904 - val_recall: 0.8365 - val_auc: 0.9305 - val_prc: 0.8792
# Epoch 19/50
# 18/18 [==============================] - 1s 84ms/step - loss: 0.2387 - tp: 2799.0000 - fp: 683.0000 - tn: 5477.0000 - fn: 257.0000 - accuracy: 0.8980 - precision: 0.8038 - recall: 0.9159 - auc: 0.9643 - prc: 0.9248 - val_loss: 0.3450 - val_tp: 691.0000 - val_fp: 238.0000 - val_tn: 1278.0000 - val_fn: 98.0000 - val_accuracy: 0.8542 - val_precision: 0.7438 - val_recall: 0.8758 - val_auc: 0.9324 - val_prc: 0.8802
# Epoch 20/50
# 18/18 [==============================] - ETA: 0s - loss: 0.2438 - tp: 2799.0000 - fp: 676.0000 - tn: 5484.0000 - fn: 257.0000 - accuracy: 0.8988 - precision: 0.8055 - recall: 0.9159 - auc: 0.9629 - prc: 0.9185Restoring model weights from the end of the best epoch: 15.
# 18/18 [==============================] - 2s 85ms/step - loss: 0.2438 - tp: 2799.0000 - fp: 676.0000 - tn: 5484.0000 - fn: 257.0000 - accuracy: 0.8988 - precision: 0.8055 - recall: 0.9159 - auc: 0.9629 - prc: 0.9185 - val_loss: 0.3270 - val_tp: 616.0000 - val_fp: 135.0000 - val_tn: 1381.0000 - val_fn: 173.0000 - val_accuracy: 0.8664 - val_precision: 0.8202 - val_recall: 0.7807 - val_auc: 0.9334 - val_prc: 0.8849
# Epoch 20: early stopping

# %% [markdown]
# **Save Model**

# %%
model.save(MODEL_NAME)

# %%
pred = model.predict(X_test).flatten()
# Out:
# 91/91 [==============================] - 2s 16ms/step

# %%
threshold =0.5
pred = np.where(pred<threshold,0,1)

# %% [markdown]
# **Model evaluation**

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay

def score_to_percent(score):
    return str(round(score * 100, 2)) + ' %'

def plot_cm(labels, predictions, p=0.5):
  cm = confusion_matrix(labels, predictions > p)
  plt.rcParams.update({'font.size': 22})
  plt.figure(figsize=(7,7))
  sns.heatmap(cm, annot=True, fmt="d",cmap='PuBu')
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')
  print("Accuracy:", score_to_percent(accuracy_score(y_test, pred)))
  print("Recall:", score_to_percent(recall_score(y_test, pred)))
  print("Precision:",score_to_percent(precision_score(y_test, pred)))
  print("F1-score:", score_to_percent(f1_score(y_test, pred)), '\n')  
  print('True Negatives: ', cm[0][0])
  print('False Positives: ', cm[0][1])
  print('False Negatives: ', cm[1][0])
  print('True Positives: ', cm[1][1])

# %%
plot_cm(y_test, pred)
# Out:
# Accuracy: 87.4 %
# Recall: 82.62 %
# Precision: 80.72 %
# F1-score: 81.66 %
#
# True Negatives:  1710
# False Positives:  193
# False Negatives:  170
# True Positives:  808

# %%
def plot_metrics(history):
  metrics = ['loss','accuracy', 'precision', 'recall','auc','prc']
  plt.figure(figsize=(20, 20), tight_layout={'h_pad': 3})
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(3,2,n+1)
    plt.plot(history.epoch, history.history[metric],  label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],label='Val')
    plt.xlabel('Epoch', fontdict={'fontsize': 15})
    plt.title(name, fontdict={'fontsize': 21, 'fontweight': 500}, pad=20)
    plt.legend(fontsize=21)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend();

# %%
plot_metrics(history)

# %% [markdown]
# **Отобразим ROC - кривую**

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
# сохраняем вероятности только для положительного исхода
lr_probs = model.predict(X_test).flatten()
threshold =0.5
pred = np.where(pred<threshold,0,1)
# рассчитываем ROC AUC
lr_auc = roc_auc_score(y_test, lr_probs)
print(': ROC AUC=%.3f' % (lr_auc))
# рассчитываем roc-кривую
fpr, tpr, treshold = roc_curve(y_test, lr_probs)
roc_auc = auc(fpr, tpr)
# строим график
plt.plot(fpr, tpr, color='darkorange',
         label='ROC кривая (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
plt.legend(loc="lower right")
plt.show()
# Out:
# 91/91 [==============================] - 2s 16ms/step
# : ROC AUC=0.935
